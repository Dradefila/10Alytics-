# %% [markdown]
# ### Table of Contents
#
# What is Exploratory Data Analysis (EDA) <br>
# Case Study Data<br>
# Basic information about the data <br>
# Data Cleaning <br>
# Univariate Analysis <br>
# Bivariate Analysis <br>
# Multivariate Analysis <br>
# Visualization
#  <br>

# %% [markdown]
# EDA is an analytic process of understanding the data in depth and to learn different characteristics of the data often with visual methods.EDA can lead to insights, which may uncover to other questions, and eventually predictive models.

# %% [markdown]
# #### Case Study Data

# %% [markdown]
# Oxy health insurance tech company wants to leverage predictive analytics and
# data-driven insights to better identify and manage its high-risk patients.
# To do this, we  need to collect, analyze, and interpret large amounts of complex data from a variety of
# sources including electronic medical records, physical files, and other claims data. Challenges include
# validating data accuracy and determining how to use the data to develop appropriate interventions for high-risk groups.
# The company must also gain a better understanding of how insurance plans affect members’ health outcomes and determine how to optimize the plan offerings.

# %% [markdown]
# The data contains age, sex, BMI, children, smoker, region and charges

# %% [markdown]
# Import Data

# %%
import pandas as pd
df=pd.read_csv('insurance.csv')
#df
# Out:
#         ID      Name   Age     Sex     bmi  children Smoker     Region  \
# 0     1001  Mick Ale  19.0  female  27.900         0    yes  southwest
# 1     1002       NaN  18.0    male  33.770         1     no  southeast
# 2     1003       NaN  28.0    male  33.000         3     no  southeast
# 3     1004       NaN  33.0    male  22.705         0     no  northwest
# 4     1005       NaN  32.0    male  28.880         0     no  northwest
# ...    ...       ...   ...     ...     ...       ...    ...        ...
# 1333  2334       NaN  50.0    male  30.970         3     no  northwest
# 1334  2335       NaN  18.0  female  31.920         0     no  northeast
# 1335  2336       NaN  18.0     NaN  36.850         0     no  southeast
# 1336  2337       NaN  21.0  female  25.800         0     no  southwest
# 1337  2338       NaN  61.0  female  29.070         0    yes  northwest
#
#           Charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# ...

# %% [markdown]
# Step 1 Understanding the raw data<br>
# To do? <br>
# Shape of the data<br>
# Top and last five rows<br>
# Datatypes<br>
# Columns

# %%
#code for Shape of the data?

# %%
# Top and last five rows?

# %%
# Datatypes?
#hint df.dtypes

# %%
# Columns ?

# %% [markdown]
# Step 2 Data preparation / cleaning <br>
# To do? <br>
# Drop columns that are less important <br>
# Fill or drop N/A rows<br>
# Rename columns<br>

# %%
#Drop columns that are less important
#hint two methods?
#df.drop(['Name'], axis=1)

# %%
#Fill or drop N/A rows
#hint
#fillna?
if df['Sex'].any():
    df['Age'] = df['Age'].fillna(value=df['Age'].mean())
else:
    df['Age'] = df['Age'].fillna(value=df['Age'].mean(male))

# %%
df.Age.isna().sum()
# Out:
# 0

# %%
df
# Out:
#         ID      Name   Age     Sex     bmi  children Smoker     Region  \
# 0     1001  Mick Ale  19.0  female  27.900         0    yes  southwest
# 1     1002       NaN  18.0    male  33.770         1     no  southeast
# 2     1003       NaN  28.0    male  33.000         3     no  southeast
# 3     1004       NaN  33.0    male  22.705         0     no  northwest
# 4     1005       NaN  32.0    male  28.880         0     no  northwest
# ...    ...       ...   ...     ...     ...       ...    ...        ...
# 1333  2334       NaN  50.0    male  30.970         3     no  northwest
# 1334  2335       NaN  18.0  female  31.920         0     no  northeast
# 1335  2336       NaN  18.0     NaN  36.850         0     no  southeast
# 1336  2337       NaN  21.0  female  25.800         0     no  southwest
# 1337  2338       NaN  61.0  female  29.070         0    yes  northwest
#
#           Charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# ...

# %%
#Rename columns
# hint df.rename(columns={"A": "Column_1", "B": "Column_2", "C": "Column_3"}, inplace = True)

# %% [markdown]
# Step 3 Feature Insights<br>
# To do? <br>
# Average Age<br>
# Most frequent Age<br>
# Male distribution<br>
# BMI outlier?<br>
# Dependent distribution<br>
# Region counts<br>
# Average charge<br>

# %%
#Average Age

# %%
#Most frequent Age
#hint df.Age.value_counts()
# Out:
# 18.0    69
# 19.0    68
# 47.0    29
# 20.0    29
# 45.0    29
# 52.0    29
# 48.0    29
# 51.0    29
# 46.0    29
# 50.0    29
# 49.0    28
# 54.0    28
# 27.0    28
# 21.0    28
# 53.0    28
# 28.0    28
# 25.0    28
# 24.0    28
# 22.0    28
# 26.0    28
# 44.0    27
# 29.0    27
# 42.0    27
# 40.0    27
# 23.0    27
# 30.0    27
# 57.0    26
# 41.0    26
# 43.0    26
# 34.0    26
# 33.0    26
# 32.0    26
# 31.0    26
# 56.0    26
# 36.0    25
# 39.0    25
# 37.0    25
# 58.0    25
# 59.0    25
# 35.0    25
# 55.0    25
# 38.0    25
# 63.0    23
# 62.0    23
# 60.0    23
# 61.0    23
# 64.0    22
# Name: Age, dtype: int64

# %%
#Male distribution<br>

# %%
#BMI outlier?<br>

# %%
#Dependent distribution<br>

# %%
#Region counts
#df.Region.unique()?
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
#Average charge

# %% [markdown]
# ## Step 4 Visuals
# #### Univariate Analysis
# meaning uni = one and variate = two. Analysis involving one variable which must contain categorical or numeric. Visualization such as Piechart, Histogram, Bar Graph, Box Plot

# %% [markdown]
# Import visual libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# plot pie chart 
#df.Sex.value_counts().plot(kind='pie', autopct='%1.0f%%', figsize=(6, 6))
# Out:
# <AxesSubplot:ylabel='Sex'>

# %%
#df['Region'].value_counts().plot(kind ='bar')
# Out:
# <AxesSubplot:>

# %%
#df['Region'].value_counts().plot(kind ='barh', title='Count of customers by Regions')
#plt.legend(title = "Variation Rate")

# %%
df.children.plot(kind='hist',figsize=(6, 6), color = 'Red')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.Charges.plot(kind='hist',bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.boxplot(x="Region", y="Charges", data=df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Charges'>

# %% [markdown]
# ## Step 5 <br>
# #### Bivariate Analysis
# refers exploratory data analysis between two varaibles. This helps with relationships between two variables eg
# Scatter Plot, Correlation

# %%
df.plot(kind='scatter',x='Age', y='Charges', c=['Green'])
plt.show()

# %%
sns.scatterplot(x='Age', y='Charges', data=df)#shift+tab
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Charges'>

# %%
df_cor=df.drop(['ID'], axis=1)

# %%
#Correlation of Independent Variables with the Dependent Variable (Charges)

# %%
df.corr()[['Charges']].sort_values(by='Charges', ascending=False)
# Out:
#            Charges
# Charges   1.000000
# Age       0.298613
# bmi       0.198341
# children  0.067998
# ID       -0.003373

# %%
plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(df.corr()[['Charges']].sort_values(by='Charges', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with Charges', fontdict={'fontsize':18}, pad=16);

# %% [markdown]
# ## Step 6 Visuals<br>
# #### Multivariate Analysis
# refers exploratory data analysis of more than two varaibles.E.g.,Correlation
# clustering, Multiple Linear Regression,

# %%
#correlation
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df_cor.corr())
# Out:
# <AxesSubplot:>

# %%
#Three columns (multivariate): two numeric and one categorical
#Clusters of different colors in the scatter plots.
sns.pairplot(
    data=df, 
    aspect=.85,
    hue='Sex')
